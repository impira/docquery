# %% [markdown]
# <a href="https://colab.research.google.com/github/amazingvince/docqa/blob/main/DocQA_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/impira/docqa.git
# !curl -sSL https://install.python-poetry.org | python3 -
# !sudo apt install tesseract-ocr
# !sudo apt-get install poppler-utils
# !cd docqa && /root/.local/bin/poetry install
# Out:
# Retrieving Poetry metadata
#
# The latest version (1.1.14) is already installed.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# poppler-utils is already the newest version (0.62.0-2ubuntu2.12).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# Updating dependencies
# Resolving dependencies... (301.3s)
#
# Writing lock file
#
# Package operations: 67 installs, 0 updates, 0 removals
#
#   • Installing pycparser (2.21): Pending...
#   • Installing pycparser (2.21): Downloading... 0%
#   • Installing pycparser (2.21): Downloading... 100%
#   • Installing pycparser (2.21): Downloading... 100%
#   • Installing pycparser (2.21): Installing...
#   • Installing pycparser (2.21)
#   • Installing cffi (1.15.1): Pending...
#   • Installing cffi (1.15.1): Downloading... 0%
#   • Installing cffi (1.15.1): Downloading... 100%
#   • Installing cffi (1.15.1): Downloading... 100%
#   • Installing cffi (1.15.1): Installing...
#   • Installing cffi (1.15.1)
#   • Installing certifi (2022.6.15): Pending...
#   • Installing charset-normalizer (2.1.1): Pending...
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing charset-normalizer (2.1.1): Pending...
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing certifi (2022.6.15): Downloading... 0%
#   • Installing charset-normalizer (2.1.1): Pending...
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing charset-normalizer (2.1.1): Downloading... 0%
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing charset-normalizer (2.1.1): Downloading... 100%
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing charset-normalizer (2.1.1): Downloading... 100%
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing charset-normalizer (2.1.1): Installing...
#   • Installing cryptography (37.0.4): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing jeepney (0.8.0): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing idna (3.3): Downloading... 0%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Pending...
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing idna (3.3): Downloading... 0%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing cryptography (37.0.4): Downloading... 0%
#   • Installing idna (3.3): Downloading... 0%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing idna (3.3): Downloading... 100%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing idna (3.3): Downloading... 100%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing charset-normalizer (2.1.1): Installing...
#   • Installing cryptography (37.0.4): Downloading... 0%
#   • Installing idna (3.3): Downloading... 100%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing certifi (2022.6.15): Downloading... 100%
#   • Installing charset-normalizer (2.1.1): Installing...
#   • Installing cryptography (37.0.4): Downloading... 0%
#   • Installing idna (3.3): Downloading... 100%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing charset-normalizer (2.1.1): Installing...
#   • Installing cryptography (37.0.4): Downloading... 0%
#   • Installing idna (3.3): Downloading... 100%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing certifi (2022.6.15): Downloading... 100%
#   • Installing charset-normalizer (2.1.1): Installing...
#   • Installing cryptography (37.0.4): Downloading... 0%
#   • Installing idna (3.3): Downloading... 100%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 100%
#   • Installing pyparsing (3.0.9): Downloading... 100%
#   • Installing charset-normalizer (2.1.1): Installing...
#   • Installing cryptography (37.0.4): Downloading... 0%
#   • Installing idna (3.3): Downloading... 100%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 100%
#   • Installing certifi (2022.6.15): Installing...
#   • Installing charset-normalizer (2.1.1): Installing...
#   • Installing cryptography (37.0.4): Downloading... 0%
#   • Installing idna (3.3): Downloading... 100%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 100%
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 100%
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Downloading... 0%
#   • Installing pyparsing (3.0.9): Downloading... 100%
#   • Installing pyparsing (3.0.9): Downloading... 100%
#   • Installing jeepney (0.8.0): Downloading... 100%
#   • Installing pyparsing (3.0.9): Downloading... 100%
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing jeepney (0.8.0): Downloading... 100%
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing cryptography (37.0.4): Downloading... 20%
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing cryptography (37.0.4): Downloading... 80%
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing cryptography (37.0.4): Downloading... 100%
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing cryptography (37.0.4): Downloading... 100%
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing cryptography (37.0.4): Installing...
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing cryptography (37.0.4): Installing...
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing charset-normalizer (2.1.1)
#   • Installing cryptography (37.0.4): Installing...
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing six (1.16.0): Pending...
#   • Installing charset-normalizer (2.1.1)
#   • Installing cryptography (37.0.4): Installing...
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing six (1.16.0): Pending...
#   • Installing certifi (2022.6.15)
#   • Installing charset-normalizer (2.1.1)
#   • Installing cryptography (37.0.4): Installing...
#   • Installing idna (3.3): Installing...
#   • Installing jeepney (0.8.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing six (1.16.0): Pending...
#   • Installing typing-extensions (4.3.0): Pending...
#   • Installing typing-extensions (4.3.0): Pending...
#   • Installing six (1.16.0): Downloading... 0%
#   • Installing typing-extensions (4.3.0): Pending...
#   • Installing typing-extensions (4.3.0): Pending...
#   • Installing six (1.16.0): Downloading... 100%
#   • Installing typing-extensions (4.3.0): Pending...
#   • Installing typing-extensions (4.3.0): Pending...
#   • Installing six (1.16.0): Downloading... 100%
#   • Installing typing-extensions (4.3.0): Pending...
#   • Installing typing-extensions (4.3.0): Pending...
#   • Installing six (1.16.0): Installing...
#   • Installing typing-extensions (4.3.0): Pending...
#   • Installing typing-extensions (4.3.0): Downloading... 0%
#   • Installing typing-extensions (4.3.0): Downloading... 100%
#   • Installing typing-extensions (4.3.0): Downloading... 100%
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing six (1.16.0): Installing...
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing jeepney (0.8.0)
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing six (1.16.0): Installing...
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing urllib3 (1.26.11): Pending...
#   • Installing jeepney (0.8.0)
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing six (1.16.0): Installing...
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing urllib3 (1.26.11): Pending...
#   • Installing idna (3.3)
#   • Installing jeepney (0.8.0)
#   • Installing pyparsing (3.0.9): Installing...
#   • Installing six (1.16.0): Installing...
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing urllib3 (1.26.11): Pending...
#   • Installing webencodings (0.5.1): Pending...
#   • Installing six (1.16.0): Installing...
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing urllib3 (1.26.11): Pending...
#   • Installing webencodings (0.5.1): Pending...
#   • Installing pyparsing (3.0.9)
#   • Installing six (1.16.0): Installing...
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing urllib3 (1.26.11): Pending...
#   • Installing webencodings (0.5.1): Pending...
#   • Installing zipp (3.8.1): Pending...
#   • Installing zipp (3.8.1): Pending...
#   • Installing webencodings (0.5.1): Downloading... 0%
#   • Installing zipp (3.8.1): Pending...
#   • Installing zipp (3.8.1): Pending...
#   • Installing webencodings (0.5.1): Downloading... 100%
#   • Installing zipp (3.8.1): Pending...
#   • Installing webencodings (0.5.1): Downloading... 100%
#   • Installing zipp (3.8.1): Pending...
#   • Installing urllib3 (1.26.11): Downloading... 0%
#   • Installing webencodings (0.5.1): Downloading... 100%
#   • Installing zipp (3.8.1): Pending...
#   • Installing zipp (3.8.1): Pending...
#   • Installing webencodings (0.5.1): Downloading... 100%
#   • Installing zipp (3.8.1): Pending...
#   • Installing zipp (3.8.1): Pending...
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Pending...
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Pending...
#   • Installing urllib3 (1.26.11): Downloading... 100%
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Pending...
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Pending...
#   • Installing urllib3 (1.26.11): Downloading... 100%
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Pending...
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Pending...
#   • Installing urllib3 (1.26.11): Installing...
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Pending...
#   • Installing zipp (3.8.1): Downloading... 0%
#   • Installing zipp (3.8.1): Downloading... 100%
#   • Installing zipp (3.8.1): Downloading... 100%
#   • Installing zipp (3.8.1): Installing...
#   • Installing idna (3.3)
#   • Installing jeepney (0.8.0)
#   • Installing pyparsing (3.0.9)
#   • Installing six (1.16.0): Installing...
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing urllib3 (1.26.11): Installing...
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Installing...
#   • Installing cryptography (37.0.4)
#   • Installing idna (3.3)
#   • Installing jeepney (0.8.0)
#   • Installing pyparsing (3.0.9)
#   • Installing six (1.16.0): Installing...
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing urllib3 (1.26.11): Installing...
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Installing...
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing urllib3 (1.26.11): Installing...
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Installing...
#   • Installing six (1.16.0)
#   • Installing typing-extensions (4.3.0): Installing...
#   • Installing urllib3 (1.26.11): Installing...
#   • Installing webencodings (0.5.1): Installing...
#   • Installing zipp (3.8.1): Installing...
#   • Installing zipp (3.8.1): Installing...
#   • Installing webencodings (0.5.1)
#   • Installing zipp (3.8.1): Installing...
#   • Installing urllib3 (1.26.11): Installing...
#   • Installing webencodings (0.5.1)
#   • Installing zipp (3.8.1): Installing...
#   • Installing typing-extensions (4.3.0)
#   • Installing urllib3 (1.26.11): Installing...
#   • Installing webencodings (0.5.1)
#   • Installing zipp (3.8.1): Installing...
#   • Installing zipp (3.8.1)
#   • Installing webencodings (0.5.1)
#   • Installing zipp (3.8.1)
#   • Installing urllib3 (1.26.11)
#   • Installing webencodings (0.5.1)
#   • Installing zipp (3.8.1)
#   • Installing bleach (5.0.1): Pending...
#   • Installing commonmark (0.9.1): Pending...
#   • Installing distlib (0.3.5): Pending...
#   • Installing docutils (0.19): Pending...
#   • Installing filelock (3.8.0): Pending...
#   • Installing importlib-metadata (4.2.0): Pending...
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing docutils (0.19): Pending...
#   • Installing filelock (3.8.0): Pending...
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Pending...
#   • Installing filelock (3.8.0): Pending...
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing filelock (3.8.0): Downloading... 0%
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Pending...
#   • Installing filelock (3.8.0): Downloading... 0%
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing commonmark (0.9.1): Downloading... 0%
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Pending...
#   • Installing filelock (3.8.0): Downloading... 0%
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing commonmark (0.9.1): Downloading... 0%
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Pending...
#   • Installing filelock (3.8.0): Downloading... 0%
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing bleach (5.0.1): Downloading... 0%
#   • Installing commonmark (0.9.1): Downloading... 0%
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Pending...
#   • Installing filelock (3.8.0): Downloading... 0%
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing filelock (3.8.0): Downloading... 0%
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Downloading... 0%
#   • Installing importlib-metadata (4.2.0): Downloading... 0%
#   • Installing importlib-metadata (4.2.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Downloading... 100%
#   • Installing filelock (3.8.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing filelock (3.8.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing commonmark (0.9.1): Downloading... 100%
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing commonmark (0.9.1): Downloading... 100%
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing commonmark (0.9.1): Installing...
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Downloading... 100%
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing commonmark (0.9.1): Installing...
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing bleach (5.0.1): Downloading... 100%
#   • Installing commonmark (0.9.1): Installing...
#   • Installing distlib (0.3.5): Downloading... 0%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing distlib (0.3.5): Downloading... 100%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing commonmark (0.9.1): Installing...
#   • Installing distlib (0.3.5): Downloading... 100%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing bleach (5.0.1): Downloading... 100%
#   • Installing commonmark (0.9.1): Installing...
#   • Installing distlib (0.3.5): Downloading... 100%
#   • Installing docutils (0.19): Downloading... 0%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing docutils (0.19): Downloading... 100%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing docutils (0.19): Downloading... 100%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing docutils (0.19): Downloading... 100%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing distlib (0.3.5): Downloading... 100%
#   • Installing docutils (0.19): Downloading... 100%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing commonmark (0.9.1): Installing...
#   • Installing distlib (0.3.5): Downloading... 100%
#   • Installing docutils (0.19): Downloading... 100%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing bleach (5.0.1): Installing...
#   • Installing commonmark (0.9.1): Installing...
#   • Installing distlib (0.3.5): Downloading... 100%
#   • Installing docutils (0.19): Downloading... 100%
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing docutils (0.19): Installing...
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing docutils (0.19): Installing...
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing distlib (0.3.5): Installing...
#   • Installing docutils (0.19): Installing...
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0): Installing...
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Pending...
#   • Installing mccabe (0.7.0): Downloading... 0%
#   • Installing mccabe (0.7.0): Downloading... 100%
#   • Installing mccabe (0.7.0): Downloading... 100%
#   • Installing mccabe (0.7.0): Installing...
#   • Installing distlib (0.3.5): Installing...
#   • Installing docutils (0.19): Installing...
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Installing...
#   • Installing commonmark (0.9.1)
#   • Installing distlib (0.3.5): Installing...
#   • Installing docutils (0.19): Installing...
#   • Installing filelock (3.8.0): Installing...
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Installing...
#   • Installing packaging (21.3): Pending...
#   • Installing packaging (21.3): Downloading... 0%
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Installing...
#   • Installing packaging (21.3): Downloading... 0%
#   • Installing filelock (3.8.0)
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Installing...
#   • Installing packaging (21.3): Downloading... 0%
#   • Installing platformdirs (2.5.2): Pending...
#   • Installing platformdirs (2.5.2): Pending...
#   • Installing packaging (21.3): Downloading... 100%
#   • Installing platformdirs (2.5.2): Pending...
#   • Installing platformdirs (2.5.2): Pending...
#   • Installing packaging (21.3): Downloading... 100%
#   • Installing platformdirs (2.5.2): Pending...
#   • Installing platformdirs (2.5.2): Pending...
#   • Installing packaging (21.3): Installing...
#   • Installing platformdirs (2.5.2): Pending...
#   • Installing platformdirs (2.5.2): Downloading... 0%
#   • Installing platformdirs (2.5.2): Downloading... 100%
#   • Installing platformdirs (2.5.2): Downloading... 100%
#   • Installing platformdirs (2.5.2): Installing...
#   • Installing docutils (0.19): Installing...
#   • Installing filelock (3.8.0)
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Installing...
#   • Installing packaging (21.3): Installing...
#   • Installing platformdirs (2.5.2): Installing...
#   • Installing distlib (0.3.5)
#   • Installing docutils (0.19): Installing...
#   • Installing filelock (3.8.0)
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Installing...
#   • Installing packaging (21.3): Installing...
#   • Installing platformdirs (2.5.2): Installing...
#   • Installing pycodestyle (2.9.1): Pending...
#   • Installing pycodestyle (2.9.1): Downloading... 0%
#   • Installing pycodestyle (2.9.1): Downloading... 100%
#   • Installing pycodestyle (2.9.1): Downloading... 100%
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing commonmark (0.9.1)
#   • Installing distlib (0.3.5)
#   • Installing docutils (0.19): Installing...
#   • Installing filelock (3.8.0)
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Installing...
#   • Installing packaging (21.3): Installing...
#   • Installing platformdirs (2.5.2): Installing...
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing bleach (5.0.1)
#   • Installing commonmark (0.9.1)
#   • Installing distlib (0.3.5)
#   • Installing docutils (0.19): Installing...
#   • Installing filelock (3.8.0)
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Installing...
#   • Installing packaging (21.3): Installing...
#   • Installing platformdirs (2.5.2): Installing...
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing pyflakes (2.5.0): Pending...
#   • Installing pyflakes (2.5.0): Downloading... 0%
#   • Installing pyflakes (2.5.0): Downloading... 100%
#   • Installing pyflakes (2.5.0): Downloading... 100%
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing filelock (3.8.0)
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Installing...
#   • Installing packaging (21.3): Installing...
#   • Installing platformdirs (2.5.2): Installing...
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing docutils (0.19)
#   • Installing filelock (3.8.0)
#   • Installing importlib-metadata (4.2.0)
#   • Installing mccabe (0.7.0): Installing...
#   • Installing packaging (21.3): Installing...
#   • Installing platformdirs (2.5.2): Installing...
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing pygments (2.13.0): Pending...
#   • Installing pygments (2.13.0): Downloading... 0%
#   • Installing pygments (2.13.0): Downloading... 60%
#   • Installing pygments (2.13.0): Downloading... 100%
#   • Installing pygments (2.13.0): Downloading... 100%
#   • Installing pygments (2.13.0): Installing...
#   • Installing packaging (21.3): Installing...
#   • Installing platformdirs (2.5.2): Installing...
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing pygments (2.13.0): Installing...
#   • Installing mccabe (0.7.0)
#   • Installing packaging (21.3): Installing...
#   • Installing platformdirs (2.5.2): Installing...
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing pygments (2.13.0): Installing...
#   • Installing pyyaml (6.0): Pending...
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing pygments (2.13.0): Installing...
#   • Installing pyyaml (6.0): Pending...
#   • Installing platformdirs (2.5.2)
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing pygments (2.13.0): Installing...
#   • Installing pyyaml (6.0): Pending...
#   • Installing requests (2.28.1): Pending...
#   • Installing platformdirs (2.5.2)
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing pygments (2.13.0): Installing...
#   • Installing pyyaml (6.0): Pending...
#   • Installing requests (2.28.1): Pending...
#   • Installing packaging (21.3)
#   • Installing platformdirs (2.5.2)
#   • Installing pycodestyle (2.9.1): Installing...
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing pygments (2.13.0): Installing...
#   • Installing pyyaml (6.0): Pending...
#   • Installing requests (2.28.1): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing requests (2.28.1): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing pyyaml (6.0): Downloading... 0%
#   • Installing requests (2.28.1): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing requests (2.28.1): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing pyyaml (6.0): Downloading... 100%
#   • Installing requests (2.28.1): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing requests (2.28.1): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing pyyaml (6.0): Downloading... 100%
#   • Installing requests (2.28.1): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing requests (2.28.1): Downloading... 0%
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing requests (2.28.1): Downloading... 0%
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing pyyaml (6.0): Installing...
#   • Installing requests (2.28.1): Downloading... 0%
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing requests (2.28.1): Downloading... 100%
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing requests (2.28.1): Downloading... 100%
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing requests (2.28.1): Installing...
#   • Installing secretstorage (3.3.3): Pending...
#   • Installing secretstorage (3.3.3): Downloading... 0%
#   • Installing secretstorage (3.3.3): Downloading... 100%
#   • Installing secretstorage (3.3.3): Downloading... 100%
#   • Installing secretstorage (3.3.3): Installing...
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing pygments (2.13.0): Installing...
#   • Installing pyyaml (6.0): Installing...
#   • Installing requests (2.28.1): Installing...
#   • Installing secretstorage (3.3.3): Installing...
#   • Installing pycodestyle (2.9.1)
#   • Installing pyflakes (2.5.0): Installing...
#   • Installing pygments (2.13.0): Installing...
#   • Installing pyyaml (6.0): Installing...
#   • Installing requests (2.28.1): Installing...
#   • Installing secretstorage (3.3.3): Installing...
#   • Installing tomli (2.0.1): Pending...
#   • Installing tomli (2.0.1): Downloading... 0%
#   • Installing tomli (2.0.1): Downloading... 100%
#   • Installing tomli (2.0.1): Downloading... 100%
#   • Installing tomli (2.0.1): Installing...
#   • Installing pygments (2.13.0): Installing...
#   • Installing pyyaml (6.0): Installing...
#   • Installing requests (2.28.1): Installing...
#   • Installing secretstorage (3.3.3): Installing...
#   • Installing tomli (2.0.1): Installing...
#   • Installing pyflakes (2.5.0)
#   • Installing pygments (2.13.0): Installing...
#   • Installing pyyaml (6.0): Installing...
#   • Installing requests (2.28.1): Installing...
#   • Installing secretstorage (3.3.3): Installing...
#   • Installing tomli (2.0.1): Installing...
#   • Installing tqdm (4.64.0): Pending...
#   • Installing tqdm (4.64.0): Downloading... 0%
#   • Installing tqdm (4.64.0): Downloading... 100%
#   • Installing tqdm (4.64.0): Downloading... 100%
#   • Installing tqdm (4.64.0): Installing...
#   • Installing requests (2.28.1): Installing...
#   • Installing secretstorage (3.3.3): Installing...
#   • Installing tomli (2.0.1): Installing...
#   • Installing tqdm (4.64.0): Installing...
#   • Installing pyyaml (6.0)
#   • Installing requests (2.28.1): Installing...
#   • Installing secretstorage (3.3.3): Installing...
#   • Installing tomli (2.0.1): Installing...
#   • Installing tqdm (4.64.0): Installing...
#   • Installing secretstorage (3.3.3): Installing...
#   • Installing tomli (2.0.1): Installing...
#   • Installing tqdm (4.64.0): Installing...
#   • Installing requests (2.28.1)
#   • Installing secretstorage (3.3.3): Installing...
#   • Installing tomli (2.0.1): Installing...
#   • Installing tqdm (4.64.0): Installing...
#   • Installing tomli (2.0.1): Installing...
#   • Installing tqdm (4.64.0): Installing...
#   • Installing secretstorage (3.3.3)
#   • Installing tomli (2.0.1): Installing...
#   • Installing tqdm (4.64.0): Installing...
#   • Installing tqdm (4.64.0): Installing...
#   • Installing tomli (2.0.1)
#   • Installing tqdm (4.64.0): Installing...
#   • Installing pyyaml (6.0)
#   • Installing requests (2.28.1)
#   • Installing secretstorage (3.3.3)
#   • Installing tomli (2.0.1)
#   • Installing tqdm (4.64.0): Installing...
#   • Installing pygments (2.13.0)
#   • Installing pyyaml (6.0)
#   • Installing requests (2.28.1)
#   • Installing secretstorage (3.3.3)
#   • Installing tomli (2.0.1)
#   • Installing tqdm (4.64.0): Installing...
#   • Installing tqdm (4.64.0)
#   • Installing cfgv (3.3.1): Pending...
#   • Installing click (8.1.3): Pending...
#   • Installing flake8 (5.0.4): Pending...
#   • Installing huggingface-hub (0.8.1): Pending...
#   • Installing identify (2.5.3): Pending...
#   • Installing isort (5.10.1): Pending...
#   • Installing identify (2.5.3): Pending...
#   • Installing isort (5.10.1): Pending...
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Pending...
#   • Installing isort (5.10.1): Pending...
#   • Installing flake8 (5.0.4): Pending...
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Pending...
#   • Installing isort (5.10.1): Pending...
#   • Installing click (8.1.3): Downloading... 0%
#   • Installing flake8 (5.0.4): Pending...
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Pending...
#   • Installing isort (5.10.1): Pending...
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Pending...
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Pending...
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing click (8.1.3): Downloading... 0%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Pending...
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing cfgv (3.3.1): Downloading... 0%
#   • Installing click (8.1.3): Downloading... 0%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Pending...
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing identify (2.5.3): Downloading... 0%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing click (8.1.3): Downloading... 0%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Downloading... 0%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing cfgv (3.3.1): Downloading... 100%
#   • Installing click (8.1.3): Downloading... 0%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Downloading... 0%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing click (8.1.3): Downloading... 0%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Downloading... 0%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing cfgv (3.3.1): Downloading... 100%
#   • Installing click (8.1.3): Downloading... 0%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Downloading... 0%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing click (8.1.3): Downloading... 0%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Downloading... 0%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing cfgv (3.3.1): Installing...
#   • Installing click (8.1.3): Downloading... 0%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 0%
#   • Installing identify (2.5.3): Downloading... 0%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing click (8.1.3): Downloading... 100%
#   • Installing flake8 (5.0.4): Downloading... 0%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 0%
#   • Installing isort (5.10.1): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 100%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 100%
#   • Installing flake8 (5.0.4): Downloading... 100%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 100%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 100%
#   • Installing flake8 (5.0.4): Downloading... 100%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 100%
#   • Installing flake8 (5.0.4): Downloading... 100%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 100%
#   • Installing click (8.1.3): Downloading... 100%
#   • Installing flake8 (5.0.4): Downloading... 100%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Downloading... 100%
#   • Installing isort (5.10.1): Installing...
#   • Installing flake8 (5.0.4): Downloading... 100%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Installing...
#   • Installing click (8.1.3): Installing...
#   • Installing flake8 (5.0.4): Downloading... 100%
#   • Installing huggingface-hub (0.8.1): Downloading... 100%
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Installing...
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Installing...
#   • Installing huggingface-hub (0.8.1): Installing...
#   • Installing identify (2.5.3): Downloading... 100%
#   • Installing isort (5.10.1): Installing...
#   • Installing isort (5.10.1): Installing...
#   • Installing identify (2.5.3): Installing...
#   • Installing isort (5.10.1): Installing...
#   • Installing huggingface-hub (0.8.1): Installing...
#   • Installing identify (2.5.3): Installing...
#   • Installing isort (5.10.1): Installing...
#   • Installing flake8 (5.0.4): Installing...
#   • Installing huggingface-hub (0.8.1): Installing...
#   • Installing identify (2.5.3): Installing...
#   • Installing isort (5.10.1): Installing...
#   • Installing click (8.1.3): Installing...
#   • Installing flake8 (5.0.4): Installing...
#   • Installing huggingface-hub (0.8.1): Installing...
#   • Installing identify (2.5.3): Installing...
#   • Installing isort (5.10.1): Installing...
#   • Installing cfgv (3.3.1)
#   • Installing click (8.1.3): Installing...
#   • Installing flake8 (5.0.4): Installing...
#   • Installing huggingface-hub (0.8.1): Installing...
#   • Installing identify (2.5.3): Installing...
#   • Installing isort (5.10.1): Installing...
#   • Installing keyring (23.8.2): Pending...
#   • Installing keyring (23.8.2): Downloading... 0%
#   • Installing keyring (23.8.2): Downloading... 100%
#   • Installing keyring (23.8.2): Downloading... 100%
#   • Installing keyring (23.8.2): Installing...
#   • Installing isort (5.10.1): Installing...
#   • Installing keyring (23.8.2): Installing...
#   • Installing identify (2.5.3)
#   • Installing isort (5.10.1): Installing...
#   • Installing keyring (23.8.2): Installing...
#   • Installing mypy-extensions (0.4.3): Pending...
#   • Installing huggingface-hub (0.8.1): Installing...
#   • Installing identify (2.5.3)
#   • Installing isort (5.10.1): Installing...
#   • Installing keyring (23.8.2): Installing...
#   • Installing mypy-extensions (0.4.3): Pending...
#   • Installing flake8 (5.0.4)
#   • Installing huggingface-hub (0.8.1): Installing...
#   • Installing identify (2.5.3)
#   • Installing isort (5.10.1): Installing...
#   • Installing keyring (23.8.2): Installing...
#   • Installing mypy-extensions (0.4.3): Pending...
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing mypy-extensions (0.4.3): Downloading... 0%
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing flake8 (5.0.4)
#   • Installing huggingface-hub (0.8.1): Installing...
#   • Installing identify (2.5.3)
#   • Installing isort (5.10.1): Installing...
#   • Installing keyring (23.8.2): Installing...
#   • Installing mypy-extensions (0.4.3): Downloading... 0%
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing click (8.1.3)
#   • Installing flake8 (5.0.4)
#   • Installing huggingface-hub (0.8.1): Installing...
#   • Installing identify (2.5.3)
#   • Installing isort (5.10.1): Installing...
#   • Installing keyring (23.8.2): Installing...
#   • Installing mypy-extensions (0.4.3): Downloading... 0%
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing mypy-extensions (0.4.3): Downloading... 100%
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing mypy-extensions (0.4.3): Downloading... 100%
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing mypy-extensions (0.4.3): Installing...
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing keyring (23.8.2): Installing...
#   • Installing mypy-extensions (0.4.3): Installing...
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing isort (5.10.1)
#   • Installing keyring (23.8.2): Installing...
#   • Installing mypy-extensions (0.4.3): Installing...
#   • Installing nodeenv (1.7.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing nodeenv (1.7.0): Downloading... 0%
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing nodeenv (1.7.0): Downloading... 100%
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing nodeenv (1.7.0): Downloading... 100%
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing identify (2.5.3)
#   • Installing isort (5.10.1)
#   • Installing keyring (23.8.2): Installing...
#   • Installing mypy-extensions (0.4.3): Installing...
#   • Installing nodeenv (1.7.0): Downloading... 100%
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing huggingface-hub (0.8.1)
#   • Installing identify (2.5.3)
#   • Installing isort (5.10.1)
#   • Installing keyring (23.8.2): Installing...
#   • Installing mypy-extensions (0.4.3): Installing...
#   • Installing nodeenv (1.7.0): Downloading... 100%
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing pdfminer.six (20220524): Pending...
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing pdfminer.six (20220524): Pending...
#   • Installing nodeenv (1.7.0): Installing...
#   • Installing numpy (1.21.1): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing pdfminer.six (20220524): Pending...
#   • Installing pathspec (0.9.0): Pending...
#   • Installing pdfminer.six (20220524): Pending...
#   • Installing numpy (1.21.1): Downloading... 0%
#   • Installing pathspec (0.9.0): Pending...
#   • Installing pdfminer.six (20220524): Pending...
#   • Installing pdfminer.six (20220524): Pending...
# ...
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing flake8-isort (4.2.0): Installing...
#   • Installing pdf2image (1.16.0): Installing...
#   • Installing pdfplumber (0.7.4): Installing...
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing build (0.8.0)
#   • Installing flake8-isort (4.2.0): Installing...
#   • Installing pdf2image (1.16.0): Installing...
#   • Installing pdfplumber (0.7.4): Installing...
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing pre-commit (2.20.0): Pending...
#   • Installing pdf2image (1.16.0): Installing...
#   • Installing pdfplumber (0.7.4): Installing...
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing pre-commit (2.20.0): Pending...
#   • Installing flake8-isort (4.2.0)
#   • Installing pdf2image (1.16.0): Installing...
#   • Installing pdfplumber (0.7.4): Installing...
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing pre-commit (2.20.0): Pending...
#   • Installing pydantic (1.9.2): Pending...
#   • Installing pdfplumber (0.7.4): Installing...
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing pre-commit (2.20.0): Pending...
#   • Installing pydantic (1.9.2): Pending...
#   • Installing pdf2image (1.16.0)
#   • Installing pdfplumber (0.7.4): Installing...
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing pre-commit (2.20.0): Pending...
#   • Installing pydantic (1.9.2): Pending...
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pydantic (1.9.2): Pending...
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pre-commit (2.20.0): Downloading... 0%
#   • Installing pydantic (1.9.2): Pending...
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pydantic (1.9.2): Downloading... 0%
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pydantic (1.9.2): Downloading... 0%
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pre-commit (2.20.0): Downloading... 100%
#   • Installing pydantic (1.9.2): Downloading... 0%
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pydantic (1.9.2): Downloading... 0%
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pre-commit (2.20.0): Downloading... 100%
#   • Installing pydantic (1.9.2): Downloading... 0%
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pydantic (1.9.2): Downloading... 0%
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pre-commit (2.20.0): Installing...
#   • Installing pydantic (1.9.2): Downloading... 0%
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing pre-commit (2.20.0): Installing...
#   • Installing pydantic (1.9.2): Downloading... 0%
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing pdfplumber (0.7.4)
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing pre-commit (2.20.0): Installing...
#   • Installing pydantic (1.9.2): Downloading... 0%
#   • Installing pytesseract (0.3.10): Pending...
#   • Installing torch (1.12.1): Pending...
#   • Installing torch (1.12.1): Pending...
#   • Installing pytesseract (0.3.10): Downloading... 0%
#   • Installing torch (1.12.1): Pending...
#   • Installing torch (1.12.1): Pending...
#   • Installing pytesseract (0.3.10): Downloading... 100%
#   • Installing torch (1.12.1): Pending...
#   • Installing torch (1.12.1): Pending...
#   • Installing pytesseract (0.3.10): Downloading... 100%
#   • Installing torch (1.12.1): Pending...
#   • Installing torch (1.12.1): Pending...
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Pending...
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Pending...
#   • Installing pydantic (1.9.2): Downloading... 20%
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Pending...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing pydantic (1.9.2): Downloading... 50%
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing pydantic (1.9.2): Downloading... 80%
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing pydantic (1.9.2): Downloading... 100%
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing pydantic (1.9.2): Downloading... 100%
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing pydantic (1.9.2): Installing...
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing build (0.8.0)
#   • Installing flake8-isort (4.2.0)
#   • Installing pdf2image (1.16.0)
#   • Installing pdfplumber (0.7.4)
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing pre-commit (2.20.0): Installing...
#   • Installing pydantic (1.9.2): Installing...
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing black (22.6.0)
#   • Installing build (0.8.0)
#   • Installing flake8-isort (4.2.0)
#   • Installing pdf2image (1.16.0)
#   • Installing pdfplumber (0.7.4)
#   • Installing pillow-simd (9.0.0.post1): Installing...
#   • Installing pre-commit (2.20.0): Installing...
#   • Installing pydantic (1.9.2): Installing...
#   • Installing pytesseract (0.3.10): Installing...
#   • Installing torch (1.12.1): Downloading... 0%
#   • Installing transformers (4.22.0.dev0 153d136): Pending...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing torch (1.12.1): Downloading... 2%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing torch (1.12.1): Downloading... 5%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing torch (1.12.1): Downloading... 8%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing torch (1.12.1): Downloading... 10%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing torch (1.12.1): Downloading... 10%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing pytesseract (0.3.10)
#   • Installing torch (1.12.1): Downloading... 10%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Pending...
#   • Installing twine (4.0.1): Downloading... 0%
#   • Installing twine (4.0.1): Downloading... 100%
#   • Installing twine (4.0.1): Downloading... 100%
#   • Installing twine (4.0.1): Installing...
#   • Installing pydantic (1.9.2): Installing...
#   • Installing pytesseract (0.3.10)
#   • Installing torch (1.12.1): Downloading... 10%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing pre-commit (2.20.0)
#   • Installing pydantic (1.9.2): Installing...
#   • Installing pytesseract (0.3.10)
#   • Installing torch (1.12.1): Downloading... 10%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing torch (1.12.1): Downloading... 12%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing torch (1.12.1): Downloading... 14%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing torch (1.12.1): Downloading... 17%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing pytesseract (0.3.10)
#   • Installing torch (1.12.1): Downloading... 17%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing pydantic (1.9.2)
#   • Installing pytesseract (0.3.10)
#   • Installing torch (1.12.1): Downloading... 17%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing torch (1.12.1): Downloading... 20%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing torch (1.12.1): Downloading... 22%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing torch (1.12.1): Downloading... 26%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1): Installing...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 30%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 34%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 37%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 40%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 44%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 50%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 54%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 59%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 60%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 64%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 68%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 70%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 73%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 76%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 80%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 85%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 90%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 95%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 99%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 100%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Downloading... 100%
#   • Installing transformers (4.22.0.dev0 153d136): Cloning...
#   • Installing twine (4.0.1)
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Building...
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136): Building...
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1): Installing...
#   • Installing transformers (4.22.0.dev0 153d136): Building...
#   • Installing twine (4.0.1)
#   • Installing pre-commit (2.20.0)
#   • Installing pydantic (1.9.2)
#   • Installing pytesseract (0.3.10)
#   • Installing torch (1.12.1): Installing...
#   • Installing transformers (4.22.0.dev0 153d136): Building...
#   • Installing twine (4.0.1)
#   • Installing pillow-simd (9.0.0.post1)
#   • Installing pre-commit (2.20.0)
#   • Installing pydantic (1.9.2)
#   • Installing pytesseract (0.3.10)
#   • Installing torch (1.12.1): Installing...
#   • Installing transformers (4.22.0.dev0 153d136): Building...
#   • Installing twine (4.0.1)
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136)
#   • Installing twine (4.0.1)
#   • Installing transformers (4.22.0.dev0 153d136)
#   • Installing twine (4.0.1)
#   • Installing torch (1.12.1)
#   • Installing transformers (4.22.0.dev0 153d136)
#   • Installing twine (4.0.1)
#
# Installing the current project: docqa (0.1.0)

# %%
# !docqa scan "who authored this paper?" https://arxiv.org/pdf/2101.07597.pdf
# Out:
# 2022-08-21 22:15:15,147 INFO: Loading https://arxiv.org/pdf/2101.07597.pdf
# 2022-08-21 22:15:15,147 INFO: Done loading files. Loading pipeline...
# 2022-08-21 22:15:17,927 INFO: Ready to start evaluating!
# https://arxiv.org/pdf/2101.07597.pdf who authored this paper?: Chengyi Wang

# %%
from docqa import document, pipeline
p = pipeline.get_pipeline()
doc = document.load_document("https://arxiv.org/pdf/2101.07597.pdf")
for q in ["Who authored this paper?", "What is the purpose of this paper?"]:
  print(q, p(question=q, **doc.context))
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'LayoutLMTokenizer'.
# The class this function is called from is 'RobertaTokenizerFast'.
# Who authored this paper? {'score': 0.98605835, 'answer': 'Chengyi Wang', 'start': 199, 'end': 200}
# What is the purpose of this paper? {'score': 0.73095775, 'answer': 'collapse', 'start': 95, 'end': 95}
